# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import pandas as pd

data = {
    'tweet': [
        "I love this product! 😍",
        "This is the worst thing ever...",
        "Meh, it’s okay I guess.",
        "Totally awesome! Would buy again.",
        "Terrible experience. Do not recommend.",
        "I'm not sure how I feel about this.",
        "Best day of my life!!",
        "Absolutely horrible. Waste of money.",
        "This was fine, nothing special.",
        "Wow! Just wow. Loved it!"
    ],
    'sentiment': [
        'positive',
        'negative',
        'neutral',
        'positive',
        'negative',
        'neutral',
        'positive',
        'negative',
        'neutral',
        'positive'
    ]
}

df = pd.DataFrame(data)
df.head()
# Out:
#                                     tweet sentiment
# 0                  I love this product! 😍  positive
# 1         This is the worst thing ever...  negative
# 2                 Meh, it’s okay I guess.   neutral
# 3       Totally awesome! Would buy again.  positive
# 4  Terrible experience. Do not recommend.  negative

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    text = re.sub(r"http\S+|www\S+|https\S+", '', text)  # Remove URLs
    text = re.sub(r'@\w+|#\w+', '', text)  # Mentions/Hashtags
    text = re.sub(r'[^A-Za-z\s]', '', text)  # Punctuation
    text = text.lower()
    tokens = text.split()  # Using split() instead of word_tokenize
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return " ".join(tokens)

df['cleaned'] = df['tweet'].apply(clean_text)
df[['tweet', 'cleaned']]
# Out:
#                                     tweet                          cleaned
# 0                  I love this product! 😍                     love product
# 1         This is the worst thing ever...                 worst thing ever
# 2                 Meh, it’s okay I guess.                   meh okay guess
# 3       Totally awesome! Would buy again.        totally awesome would buy
# 4  Terrible experience. Do not recommend.    terrible experience recommend
# 5     I'm not sure how I feel about this.                     im sure feel
# 6                   Best day of my life!!                    best day life
# 7    Absolutely horrible. Waste of money.  absolutely horrible waste money
# 8         This was fine, nothing special.             fine nothing special
# 9                Wow! Just wow. Loved it!                    wow wow loved

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Convert text into numerical vectors
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df['cleaned'])
y = df['sentiment']

# %%
from sklearn.model_selection import train_test_split

# Split into training and testing sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# Create and train model
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
print(predict_sentiment("This product is amazing!"))          # should be positive
print(predict_sentiment("I hate it so much."))                # should be negative
print(predict_sentiment("It's okay, not too bad."))           # should be neutral
print(predict_sentiment("The experience was terrible."))      # should be negative
print(predict_sentiment("I loved using this app."))           # should be positive
# Out:
# positive
# positive
# positive
# negative
# positive

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train, y_train)
Then test again with:

python
Copy
Edit
print(predict_sentiment("This product is amazing!"))          # should be positive
print(predict_sentiment("I hate it so much."))               # should be negative
print(predict_sentiment("It's okay, not too bad."))          # should be neutral
# Out:
#   File "/tmp/ipython-input-17-3201305800.py", line 5
#     Then test again with:
#          ^
# SyntaxError: invalid syntax

# %%
from sklearn.naive_bayes import MultinomialNB

# Train the model
model = MultinomialNB()
model.fit(X_train, y_train)

# Test predictions
print(predict_sentiment("This product is amazing!"))
print(predict_sentiment("I hate it so much."))
print(predict_sentiment("It's okay, not too bad."))
# Out:
# positive
# positive
# positive
